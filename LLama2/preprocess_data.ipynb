# %%
import pandas as pd 
import numpy as np
import re
from tqdm import tqdm

# %%
import os 

os.getcwd()
# Out:
# '/home/vitruv/llamata'

# %%
df = pd.read_excel('data/ver0_2_1dataset.xlsx')
df
# Out:
#                                                  query  \
# 0    그레이시와 조는 복소평면에서 숫자를 선택하고 있습니다. 조는 $1+2i$ 점을 선택...
# 1    한명의 축구 선수가 25달러의 운동복, 15.20달러의 반바지와 6.80달러의 양말...
# 2    디에고는 그의 여동생 생일을 위해 12개의 케이크를 만들었습니다. 도널드 역시 4개...
# 3                              $10101_3$를 10진수로 변환합니다.
# 4    수아는 공장에서 일하고 있고, 매 30분마다 그녀가 감독하는 기계가 30개의 소다 ...
# ..                                                 ...
# 993  $b$와 $c$가 실제 숫자가 되도록 합시다. 만일 다수 $x^2+bx+c$가 정확...
# 994   $\frac{3 \cdot 5! + 15\cdot 4!}{6!}$의 가치는 무엇일까요?
# 995         $y = 4x^2 - 3$ 방정식으로 정의된 파라볼라의 집중도는 무엇일까요?
# 996  해마다 도마뱀이 낳는 30개의 알 중 20%는 임신불능이고 나머지 1/3은 낙태로 ...
# 997  크리스틴이 12마리의 바퀴벌레를 가지고 있고 크리스틴이 1/4마리의 바퀴벌레를 가지...
#
#                                               response
# 0    \n풀이 과정 : 천천히 단계별로 풀어볼게요.  \n\n[1단계] 복소 평면 위의 ...
# 1    \n풀이 과정 : 천천히 단계별로 풀어볼게요.  \n\n각각의 선수들은 $25의 제...
# 2    \n풀이 과정 : 천천히 단계별로 풀어볼게요.  \n\n[1단계] 변수의 의미 파악...
# 3    \n풀이 과정 : 천천히 단계별로 풀어볼게요.  \n\n[1단계] 문제의 요구사항 ...
# 4    \n풀이 과정 : 천천히 단계별로 풀어볼게요.  \n\n[1단계] 생산량 계산\n우...
# ..                                                 ...
# 993  만약 사각형이 정확히 하나의 진정한 뿌리를 가지고 있다면, 격차선은 0과 같아야 합...
# 994  첫째로, 숫자를 단순화합니다. $3 \cdot 5! + 15 \cdot 4! = 3...
# 995  꼭대기 형태의 파라볼라의 방정식은 $y = a(x-h)^2 + k$ 이고, $(h,...
# 996  30개의 알 중에서 20%가 불임성입니다. 그래서 30 * 0.2 = 6개의 알은 ...
# 997  크리스틴이 12마리의 바퀴벌레를 가지고 있다면 크리스는 1/4*12=3마리의 바퀴벌...
#
# [998 rows x 2 columns]

# %%
df1 = pd.read_excel('data/math_norm.xlsx')
df1
# Out:
#         title                                            content
# 0     드모르간 법칙  합집합의 여집합은 여집합의 교집합이고, 교집합의 여집합은 여집합의 합집합이다. 이것...
# 1     상관관계 측도  대부분의 투자는 한 종목만으로 이루어지는 것이 아니라 여러 종목으로 구성된 투자 포...
# 2        미분형식  일반적인 미분다양체에서 함수들을 적분하는 자연스러운 방법은 존재하지 않는다. 하지만...
# 3        측지곡률  평면 곡선의 곡률은 평면 안에서 곡선이 굽어 있는 정도를 측정하는 양이다. 만약, ...
# 4       특수선형군             정사각행렬 중 행렬식이 1인 것들이 이루는 군(group)을 말한다.
# ...       ...                                                ...
# 2089     부분집합               꽃은 식물이므로, 꽃들의 집합은 식물들 전체 집합의 부분집합이다.
# 2090      합집합  춤 추는 것을 좋아하는 사람들의 집합과 꿈이 많은 여자들의 집합의 합집합은  춤 추...
# 2091      교집합  자연수 중에서 짝수 전체로 이루어진 집합과   $3$의 배수 전체로 이루어진 집합의...
# 2092      공집합              집합을 주머니에 비유한다면, 공집합은  빈 주머니라고 할 수 있다.
# 2093      점화식  점화식은 수열의 일반항을 한 개 이상의 앞선 항들을 이용하여 나타낸 식이다. 즉, ...
#
# [2094 rows x 2 columns]
